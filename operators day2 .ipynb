# %% [markdown]
# # Logical Operator :- AND OR NOT    AND Comparison Operator

# %% [markdown]
# # OR operator

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False   # This is all the Logical or operator
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True - False  # The value of a True is 1 and False 0
# Out:
# 1

# %%
5>5
# Out:
# False

# %%
5>=5
# Out:
# True

# %%
5==5
# Out:
# True

# %%
5 > 1 & 10 < 20  # True & True
# Out:
# True

# %%
'hello' == 'hello'
# Out:
# True

# %%
'Hello' == 'hello'
# Out:
# False

# %%
'hi' != 'by'
# Out:
# True

# %%
'exit' != 'exit'
# Out:
# False

# %%
age = 37

# %%
print('My age is', age)
# Out:
# My age is 37

# %%
print(f'My age is {age}  and i am very good person')
# Out:
# My age is 37  and i am very good person

# %%
name = "Tanmay"

# %%
print(f'My name is {name}')
# Out:
# My name is Tanmay

# %%
name = input("Enter your good name")
print(f'My name is {name}')
# Out:
# Enter your good name Tanmay
# My name is Tanmay

# %%
(type(name))
# Out:
# str

# %%
age = int(input("Enter your age"))
print(f'your age is {age}')
# Out:
# Enter your age 21
# your age is 21

# %%
type(age)
# Out:
# int

# %%
student_name = input('Enter student name')
marks = float(input('Enter your marks'))
print(f'Student name is {student_name} and marks are {marks} ')
# Out:
# Enter student name Tanmay
# Enter your marks 90
# Student name is Tanmay and marks are 90.0

# %% [markdown]
# # Data Strucuture

# %%
l = [1,2,3,4,5]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
mix = [1,15.2,10+5j,True, 'Hello']

# %%
mix
# Out:
# [1, 15.2, (10+5j), True, 'Hello']

# %%
type(mix)
# Out:
# list
