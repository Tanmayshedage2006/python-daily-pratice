# %% [markdown]
# # Arithmetic Operators

# %%
10+5
# Out:
# 15

# %%
10-5
# Out:
# 5

# %%
"Hello" * 5
# Out:
# 'HelloHelloHelloHelloHello'

# %%
10 * 0
# Out:
# 0

# %%
10/2
# Out:
# 5.0

# %%
1233/7
# Out:
# 176.14285714285714

# %%
1233//7 # in simple it takes complete number
# Out:
# 176

# %%
2**2
# Out:
# 4

# %%
10**2
# Out:
# 100

# %% [markdown]
# # logic square of number

# %%
num=2

# %%
num**2
# Out:
# 4

# %%
num*num
# Out:
# 4

# %% [markdown]
# # Module --> Logic even and odd code

# %%
12 % 2
# Out:
# 0

# %%
12/2
# Out:
# 6.0

# %%
13 % 2
# Out:
# 1

# %%
1312 % 2
# Out:
# 0

# %% [markdown]
# # Assignement Operator

# %%
num1 = 5

# %%
num1 = num1 + 1

# %%
num1
# Out:
# 3

# %%
num1 += 4

# %%
num1
# Out:
# 7

# %%
num2 = 15

# %%
num2 = num2 - 5 # 15 - 5

# %%
num2
# Out:
# 10

# %%
num2 -= 5

# %%
num2
# Out:
# 5

# %%
num3 = 10

num3 = num3 / 2

# %%
num3
# Out:
# 5.0
