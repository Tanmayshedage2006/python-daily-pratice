# %% [markdown]
# # Numeric data types

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
33.00
type(33.00)
# Out:
# float

# %%
type(10+5j)
# Out:
# complex

# %% [markdown]
# # string Data Type

# %%
print('python')
# Out:
# python

# %%
print('Today i am learning data types') # single line
# Out:
# Today i am learning data types

# %%
print('''This is my first line.
This is my second line.
This is my third line.''')  # mulitple line
# Out:
# This is my first line.
# This is my second line.
# This is my third line.

# %%
'''This is my first line.
This is my second line.
This is my third line.''' # showing that \n is needed for this (\n use for new line)
# Out:
# 'This is my first line.\nThis is my second line.\nThis is my third line.'
