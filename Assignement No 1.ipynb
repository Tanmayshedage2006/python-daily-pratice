# %% [raw]
# 1:-In the below elements which of them are value or an expresesion?
# eg:- values can be a intger or string and experssios will ne mathematical operators.

# %% [raw]
# ANS:-
# # There are a total of 4 operator and 3 Expression They are:
#  Operators :- +,-,/,+
#  Expression :- 'hello',87.6,6,

# %% [raw]
# 2:-What is the difference between string and variable?

# %%
a="Tanmay" # string is a group of character usally enclosed with the "" or ''
a= 4 # Variable is used to store information and a string

# %% [raw]
# 3:- Describe the three data types?

# %%
# Three fundamental Data types in python are int float complex
int = 3 #  To reprsent  whole number
float = 3.8 # To reprsent floating point vlaue 
complex = 10+5j # To repsent is complex class

# %% [raw]
# 4 :- What is an expression made up of ?  What  do all expression do ?

# %%
4*5+20-40 # Is an  expression in python
# Out:
# 0

# %% [raw]
# 5:- The assignement statments, like spam = 10. What is the difference between an expression and a stament

# %%
4*5+20-40 # Is an expression
couseName="In Neuron Fullstack DataScience" # Is a statment

# %% [raw]
# 6 :- After running the follwing code, what does the variable bacon contain?
# bacon=22
# bacon+1

# %%
bacon=22 # The bacon is set to 22 . The expression bacon+1 does not reassign the value in bacon(that would the case )
bacon+1
# Out:
# 23

# %% [raw]
# 7:- What should the values of the follwing two terms be ?
#  'spam'+'spamspam'
#   'spam'*3

# %%
print("spam"+"spamspam")
print('spam'*3)
# Out:
# spamspamspam
# spamspamspam

# %% [raw]
# Why is eggs is valid variable name while 100 is invalid?

# %%
egg="hello" # variable can start with letter or the underscore character 
100="hello" # variable cannot start with a number
# In python there are rules for naming a varible
# Out:
#   Cell In[22], line 2
#     100="hello" # variable cannot start with a number
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [raw]
# 9:- What three functions can be used to get the integer, floating-point number.or string version of a vlaue

# %% [raw]
# 10:- why does this expression cause an error? how can you fix ot ?
#  'I have eaten' + 99 + 'burritos'

# %%
print('I have eaten')
