# %% [markdown]
# # Variables and how to declare it

# %%
a=5

# %%
a
# Out:
# 5

# %%
b=3

# %%
b
# Out:
# 3

# %%
a+b
# Out:
# 8

# %%
type(b)
# Out:
# int

# %%
c=a+b

# %%
c
# Out:
# 8

# %%
x,y,z=3,4,5

# %%
x
# Out:
# 3

# %%
y
# Out:
# 4

# %%
z
# Out:
# 5

# %%
o = 1,2,3,4,5

# %% [markdown]
# # How to declare variables

# %%
a5=20

# %% [markdown]
# a5

# %%
a_5=10

# %%
a 5 = 20  # We can't add space into it
# Out:
#   Cell In[24], line 1
#     a 5 = 20
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Conctentaion

# %%
name="Tanmay"

# %%
name
# Out:
# 'Tanmay'

# %%
lastname="Shedage"

# %%
name+lastname  # in simple conctenation means add one data type to another
# Out:
# 'TanmayShedage'

# %% [markdown]
# #operartion

# %%
name
# Out:
# 'Tanmay'

# %%
lastname
# Out:
# 'Shedage'

# %%
name+' '+lastname
# Out:
# 'Tanmay Shedage'

# %%
num='5'

# %%
type(num)
# Out:
# str

# %%
int (99.00) # This method is called typecastig (typecass)
# Out:
# 99
