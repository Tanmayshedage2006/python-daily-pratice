# %% [markdown]
# #  if else

# %%
if 1>5:
    print[True]
else:
    print(False)
# Out:
# False

# %%
1>5
# Out:
# False

# %%
if 10 > 35:
    print("pass")
else:
    print("Fail")
# Out:
# Fail

# %%
marks = float(input("Enter your marks"))

if marks > 35:
    print("pass")
else:
    print("Fail")
# Out:
# Enter your marks 60
# pass

# %%
marks = float(input("Enter your marks"))

if marks >= 90:
    print('A')
elif marks >= 70:
    print('B')
elif marks >= 50:
    print('C')
elif marks >= 35 :
    print("pass")
else:
    print("Fail")
# Out:
# Enter your marks 20
# Fail

# %% [raw]
# # COURSE INFO

# %%
course = input("Enter your course name")

if course == 'python':
    print("Yes we have python course")
elif course == 'java':
    print("We have java course")
else:
    print(f"we don't have {course} course")
# Out:
# Enter your course name cloud devops
# we don't have cloud devopscourse

# %%
'java'=='python'
# Out:
# False

# %%
'java' == 'java'
# Out:
# True

# %%
course = input("Enter your course name")

if course == 'python':
    print("Yes we have python course")
elif course == 'java':
    print("We have java course")
else:
    print(f"we don't have {course} course")
# Out:
# Enter your course name python
# Yes we have python course

# %% [raw]
# 'JA'.lower()

# %%
'java'.upper()
# Out:
# 'JAVA'

# %%
coupon= input('Enter your coupon code')
total=float(input("Enter your total bill"))

if coupon == 'DATA50':
    discount = total*0.5
    print(f'you will get discount of {discount}')
    final_price = print(f'Your final total bill is {total-discount}')
elif coupon == "DATA70":
    discount = total*0.7
    print(f'you will get discount of {discount}')
    final_price = print(f'Your final total bill is {total-discount}')
else:
    print('Coupon code is not valid')
    print(f'Your final price will be {total}')
# Out:
# Enter your coupon code 3e03
# Enter your total bill 3333
# Coupon code is not valid
# Your final price will be 3333.0

# %%
marks = float(input("Enter your marks"))

if marks >= 90 and marks <= 100:
    print('A')
elif marks >= 70 and marks < 90:
    print('B')
elif marks >= 50 and marks < 70:
    print('C')
elif marks >= 35 and marks < 50:
    print("pass")
elif marks >= 0 and marks <35:
    print("Fail")
else:
    print("please write marks between 0-100 range")
# Out:
# Enter your marks 222
# please write marks between 0-100 range

# %% [markdown]
#  even and odd

# %%
num = int(input("Enter your num"))
if num % 2 == 0:
    print('Even num',num)
elif num % 2 == 0:
    print9('odd',num)
else:
    print('please rewrite num')
# Out:
# Enter your num 2
# Even num 2
