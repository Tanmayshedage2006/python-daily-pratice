# %%
def great():
    print("Hello how are you")

# %%
great()
# Out:
# Hello how are you

# %%
def square(num):
    result = num*num
    print(result)

# %%
square(4)
# Out:
# 16

# %%
square(8)
# Out:
# 64

# %%
def square(num):
    """ THis is sqauare function.        
    You have to give input for num.
    It will return square of num"""
    result=num*num
    print(result)

# %%
square(933)
# Out:
# 870489

# %%
def even_odd(num):
    if num % 2 ==0:
        print("Even",num)
    else :
        print("odd",num)

# %%
even_odd(93)
# Out:
# odd 93

# %%
def test(a):
    print(a+100)

# %%
test(3)
# Out:
# 103

# %%
type(square(3))
# Out:
# 9
# NoneType

# %%
def new_square(num):
    result=num*num
    return result

# %%
new_square(8)
# Out:
# 64

# %%
type(new_square(8))
# Out:
# int

# %%
def test2(n):
    for i in range(1,n):
        print(i)

# %%
test2(9)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
def test3(n):
    for i in range (1,n):
        return i

# %%
test3(3)
# Out:
# 1

# %%
def test4(n):
    l=[] # local variable
    for i in range(1,n):
        l.append(i)
    return l

# %%
test4(6)
# Out:
# [1, 2, 3, 4, 5]

# %%
o=[1,2,3,4,5,6] # global

# %%
o
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def test5(marks):
    if marks > 90:
        return 'A'
    elif marks> 50:
        return 'B'
    else:
        return 'Fail'

# %%
test5(78)
# Out:
# 'B'

# %%
def sum_num(n):
    total=0
    for i in range(1,n+1):
        total=total + i
    return total

# %%
sum_num(10)
# Out:
# 55

# %%
sum_num(5)
# Out:
# 15

# %%
def test5(a,b,c,d,r,t):
    return a,b,c,d,r,t

# %%
test5(1,9,9,9,9,9)
# Out:
# (1, 9, 9, 9, 9, 9)

# %%
def test6(*args):
    return args

# %%
test6(2,4,5,6,'hello',True,23,4,3,43)
# Out:
# (2, 4, 5, 6, 'hello', True, 23, 4, 3, 43)

# %%
def test7(*args):
    l=[]
    for i in args:
        if type(i) == int:
            l.append(i)
    return l

# %%
test7(3,8,9,"hello",True,45.9,89)
# Out:
# [3, 8, 9, 89]

# %%
def test8(*args):
    l=[]
    for i in args:
        if type(i) == int:
            l.append()
        elif type(i) == list:
            l.append()
        elif type(i) == list:
            l.append()
        return l

# %%
def test9(**kwargs):
    return kwargs

# %%
test9(a=5,b=90,c=11)
# Out:
# {'a': 5, 'b': 90, 'c': 11}

# %%
def test11(*args,**kwargs):
    return args,kwargs

# %%
test11(1,3,34,5,4,a=3,b=5,c=5)
# Out:
# ((1, 3, 34, 5, 4), {'a': 3, 'b': 5, 'c': 5})

# %%
def test12(a,c,*args,**kwargs):
    return a,c,args,kwargs

# %%
test12(2,2,3,43,3,3,a=3,c=3,g=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 test12(2,2,3,43,3,3,a=3,c=3,g=5)
#
# TypeError: test12() got multiple values for argument 'a'
